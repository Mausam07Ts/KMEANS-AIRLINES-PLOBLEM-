# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans

# %%
excel_file = 'EastWestAirlines.xlsx'
ew_a = pd.read_excel(excel_file)

# %%
ew_a#not needed
# Out:
#    East-West Airlines is trying to learn more about its customers.  Key issues are their  ...                                         Unnamed: 4
# 0   flying patterns, earning and use of frequent f...                                     ...                                                NaN
# 1   card.  The task is to identify customer segmen...                                     ...                                                NaN
# 2                                                 NaN                                     ...                                                NaN
# 3                                                 NaN                                     ...                                                NaN
# 4   Source: Based upon real business data; company...                                     ...                                                NaN
# ...

# %%
airlines_sheet1 = pd.read_excel(excel_file, sheet_name=1)#2nd Sheet where the data is present

# %%
airlines_sheet1
# Out:
#        ID#  Balance  Qual_miles  ...  Flight_trans_12  Days_since_enroll  Award?
# 0        1    28143           0  ...                0               7000       0
# 1        2    19244           0  ...                0               6968       0
# 2        3    41354           0  ...                0               7034       0
# 3        4    14776           0  ...                0               6952       0
# 4        5    97752           0  ...                4               6935       1
# ...    ...      ...         ...  ...              ...                ...     ...
# 3994  4017    18476           0  ...                1               1403       1
# 3995  4018    64385           0  ...                0               1395       1
# 3996  4019    73597           0  ...                0               1402       1
# 3997  4020    54899           0  ...                1               1401       0
# 3998  4021     3016           0  ...                0               1398       0
#
# ...

# %%
airlines_sheet1.describe()
# Out:
#                ID#       Balance  ...  Days_since_enroll       Award?
# count  3999.000000  3.999000e+03  ...         3999.00000  3999.000000
# mean   2014.819455  7.360133e+04  ...         4118.55939     0.370343
# std    1160.764358  1.007757e+05  ...         2065.13454     0.482957
# min       1.000000  0.000000e+00  ...            2.00000     0.000000
# 25%    1010.500000  1.852750e+04  ...         2330.00000     0.000000
# 50%    2016.000000  4.309700e+04  ...         4096.00000     0.000000
# 75%    3020.500000  9.240400e+04  ...         5790.50000     1.000000
# max    4021.000000  1.704838e+06  ...         8296.00000     1.000000
#
# [8 rows x 12 columns]

# %%
air = airlines_sheet1.drop(labels='ID#', axis=1)

# %%
air
# Out:
#       Balance  Qual_miles  ...  Days_since_enroll  Award?
# 0       28143           0  ...               7000       0
# 1       19244           0  ...               6968       0
# 2       41354           0  ...               7034       0
# 3       14776           0  ...               6952       0
# 4       97752           0  ...               6935       1
# ...       ...         ...  ...                ...     ...
# 3994    18476           0  ...               1403       1
# 3995    64385           0  ...               1395       1
# 3996    73597           0  ...               1402       1
# 3997    54899           0  ...               1401       0
# 3998     3016           0  ...               1398       0
#
# [3999 rows x 11 columns]

# %%
air.dtypes
# Out:
# Balance              int64
# Qual_miles           int64
# cc1_miles            int64
# cc2_miles            int64
# cc3_miles            int64
# Bonus_miles          int64
# Bonus_trans          int64
# Flight_miles_12mo    int64
# Flight_trans_12      int64
# Days_since_enroll    int64
# Award?               int64
# clusterid_new        int32
# dtype: object

# %%
air.isnull().sum()
# Out:
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award?             3999 non-null   int64
# dtypes: int64(11)
# memory usage: 343.8 KB

# %%
air.corr()
# Out:
#                     Balance  Qual_miles  ...    Award?  clusterid_new
# Balance            1.000000    0.108722  ...  0.178494       0.349826
# Qual_miles         0.108722    1.000000  ...  0.095256       0.046738
# cc1_miles          0.338344    0.007931  ...  0.335457       0.830096
# cc2_miles         -0.008804   -0.013923  ...  0.005332      -0.050350
# cc3_miles          0.035243   -0.007779  ...  0.023484       0.148830
# Bonus_miles        0.403487    0.031021  ...  0.373506       0.689907
# Bonus_trans        0.324935    0.050725  ...  0.333893       0.600481
# Flight_miles_12mo  0.217551    0.126774  ...  0.217715       0.099203
# Flight_trans_12    0.255700    0.144004  ...  0.247909       0.104378
# Days_since_enroll  0.263129    0.017312  ...  0.188121       0.265088
# Award?             0.178494    0.095256  ...  1.000000       0.437408
# clusterid_new      0.349826    0.046738  ...  0.437408       1.000000
#
# [12 rows x 12 columns]

# %%
#Normalization of the Data
def norm_df(i):
    x = (i-i.min())/(i.max()-i.min())
    return(x)

# %%
normal_data=norm_df(air)
normal_data
# Out:
#        Balance  Qual_miles  ...  Days_since_enroll  Award?
# 0     0.016508         0.0  ...           0.843742     0.0
# 1     0.011288         0.0  ...           0.839884     0.0
# 2     0.024257         0.0  ...           0.847842     0.0
# 3     0.008667         0.0  ...           0.837955     0.0
# 4     0.057338         0.0  ...           0.835905     1.0
# ...        ...         ...  ...                ...     ...
# 3994  0.010837         0.0  ...           0.168917     1.0
# 3995  0.037766         0.0  ...           0.167953     1.0
# 3996  0.043169         0.0  ...           0.168797     1.0
# 3997  0.032202         0.0  ...           0.168676     0.0
# 3998  0.001769         0.0  ...           0.168314     0.0
#
# [3999 rows x 11 columns]

# %%
#The K-means algorithm aims to choose centroids that minimise the inertia, or within-cluster sum-of-squares criterion:

# %%
wcss=[]
for i in range(1, 11):
  kmeans=KMeans(n_clusters=i, random_state=0)
  kmeans.fit(normal_data)
  wcss.append(kmeans.inertia_)

plt.plot(range(1,11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#Build Cluster algorithm
from sklearn.cluster import KMeans
clusters_new = KMeans(5, random_state=42)#Clustering based on k=5 coz curve doesnt change much after that
clusters_new.fit(normal_data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
clusters_new.labels_
# Out:
# array([4, 4, 4, ..., 1, 0, 0], dtype=int32)

# %%
#Assign clusters to the data set
airlines_sheet1['clusterid_new'] = clusters_new.labels_

# %%
airlines_sheet1
# Out:
#        ID#  Balance  Qual_miles  ...  Days_since_enroll  Award?  clusterid_new
# 0        1    28143           0  ...               7000       0              4
# 1        2    19244           0  ...               6968       0              4
# 2        3    41354           0  ...               7034       0              4
# 3        4    14776           0  ...               6952       0              4
# 4        5    97752           0  ...               6935       1              1
# ...    ...      ...         ...  ...                ...     ...            ...
# 3994  4017    18476           0  ...               1403       1              3
# 3995  4018    64385           0  ...               1395       1              3
# 3996  4019    73597           0  ...               1402       1              1
# 3997  4020    54899           0  ...               1401       0              0
# 3998  4021     3016           0  ...               1398       0              0
#
# ...

# %%
airlines_sheet1.groupby('clusterid_new').agg(['mean']).reset_index()
# Out:
#   clusterid_new          ID#  ... Days_since_enroll Award?
#                         mean  ...              mean   mean
# 0             0  3204.917636  ...       1992.402132      0
# 1             1  1613.016089  ...       4863.439356      1
# 2             2  1840.462783  ...       4419.553398      0
# 3             3  1904.763744  ...       4338.867756      1
# 4             4  1183.362903  ...       5567.925115      0
#
# [5 rows x 13 columns]

# %%
# from above cluster gropu by we infer that id's or people beloing to cluster 1 ,2,3 have large balances and have flwn lot of miles to qualify ,especially
#cluster 1.But we see people of cluster 1 and 3 are more likely recepient of awards and have flown more qualification miles
